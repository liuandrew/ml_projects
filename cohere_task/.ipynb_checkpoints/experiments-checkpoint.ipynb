# %%
import os
import numpy as np
import pandas as pd
import pickle
from tqdm import tqdm
import matplotlib.pyplot as plt
folder = 'training_20180910/'

# %%
txts = [file for file in os.listdir(folder) if '.txt' in file]
anns = [file for file in os.listdir(folder) if '.ann' in file]
ids = [file.strip('.txt') for file in txts]

# %%
def load_txt(txt=None, i=None):
    '''
    Pass text file name or index to load file
    '''
    if txt is not None:
        with open(folder + txt) as f:
            lines = f.readlines()
        return lines
    elif i is not None:
        with open(folder + txts[i]) as f:
            lines = f.readlines()
        return lines
    
def load_txt(txt=None, i=None):
    '''
    Pass text file name or index to load file
    '''
    if txt is not None:
        with open(folder + txt) as f:
            lines = f.readlines()
        return lines
    elif i is not None:
        with open(folder + txts[i]) as f:
            lines = f.readlines()
        return lines


'''
Get chief complaint and history from medical record
Save to patient_record_summary.pickle
'''
patient_text_rows = []
            
for patient_id in ids:
    patient_text = {}
    
    txt = patient_id + '.txt'
    lines = load_txt(txt)
    
    # get chief complaint
    chief_complaint = ''
    chief_complaint_idx = -1
    chief_complaint_end_idx = -1
    
    # start and end of chief complaint
    for i, line in enumerate(lines):
        if 'chief complaint' in line.lower():
            chief_complaint_idx = i
            break
    for j, line in enumerate(lines[i:]):
        if line == '\n':
            chief_complaint_end_idx = j + i
            break
    
    # trim \n and join
    if chief_complaint_idx > -1:
        chief_complaint = lines[chief_complaint_idx:chief_complaint_end_idx]
        chief_complaint = [line.strip('\n') for line in chief_complaint]
        chief_complaint = ' '.join(chief_complaint)
        
    patient_text['chief_complaint'] = chief_complaint

    
    # get present history
    present_history = ''
    present_history_idx = -1
    present_history_end_idx = -1
    
    for i, line in enumerate(lines):
        if 'history of present illness' in line.lower():
            present_history_idx = i
            break
    for j, line in enumerate(lines[i+3:]):
        #find the next header
        if ':' in line:
            present_history_end_idx = j + i + 3
            break
    
    if present_history_idx > -1:
        present_history = lines[present_history_idx:present_history_end_idx]
        present_history = [line.strip('\n') for line in present_history]
        present_history = ' '.join(present_history)
    
    patient_text['present_history'] = present_history
    
    
    patient_text_rows.append(patient_text)
    
patient_df = pd.DataFrame(patient_text_rows, index=ids)
patient_df.to_csv('patient_record_summary.csv')

# %%
corpus2 = list(patient_df['chief_complaint'] + ' \n ' + patient_df['present_history'])

# %%
from sklearn import feature_extraction
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity

# Perform Tf-Idf on present-history documents
vectorizer = feature_extraction.text.TfidfVectorizer()
# corpus = list(patient_df['present_history'])
vectors = vectorizer.fit_transform(corpus2)

mat = cosine_similarity(vectors, vectors)

modelkmeans = KMeans()
modelkmeans.fit(vectors)

# Attempt to find ideal number of clusters
# sum_of_squared_dists = []
# K = range(1, 150)
# for k in tqdm(K):
#     km = KMeans(n_clusters=k)
#     km = km.fit(vectors)
#     sum_of_squared_dists.append(km.inertia_)

plt.plot(K[:len(sum_of_squared_dists)], sum_of_squared_dists)
plt.scatter(K[13], sum_of_squared_dists[13])

# %%
kmeans = KMeans(3)
cluster_x = kmeans.fit_predict(vectors)
for i in range(3):
    print(np.sum(cluster_x == i))
# Out:
# 80
# 116
# 107

# %%
from sklearn.decomposition import PCA
pca = PCA(2)
pca_x = pca.fit_transform(vectors.todense())

# %%
plt.scatter(pca_x.T[0], pca_x.T[1], c=cluster_x)

# %%
cluster_x == 0
# Out:
# array([False,  True, False, False, False, False, False, False, False,
#        False,  True, False,  True,  True, False,  True, False, False,
#        False, False, False, False,  True, False,  True, False, False,
#         True, False, False, False,  True, False, False, False,  True,
#        False, False,  True, False,  True,  True,  True,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False,  True, False, False, False,
#        False, False, False, False, False,  True, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False,  True, False, False, False,
#         True, False, False, False, False, False,  True,  True, False,
#        False,  True, False,  True, False, False,  True, False, False,
#         True,  True, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False,  True,  True, False,
#        False, False, False, False, False,  True, False, False, False,
#        False,  True,  True, False, False,  True, False, False,  True,
#        False, False, False,  True, False, False,  True,  True, False,
#        False, False,  True, False, False, False,  True,  True,  True,
#        False, False, False, False,  True,  True,  True, False, False,
#        False, False, False,  True, False,  True, False, False,  True,
#        False, False,  True, False, False, False,  True, False,  True,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True,  True, False,
#        False, False, False,  True, False, False, False,  True, False,
#         True, False,  True, False, False,  True, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#         True,  True, False, False, False, False,  True, False,  True,
#         True,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False,  True, False,  True, False, False, False, False,
#         True, False, False, False,  True,  True, False,  True,  True,
#         True, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False,  True, False, False,
#        False, False, False, False,  True, False])

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(2, perplexity=5)
tsne_x = tsne.fit_transform(vectors.todense())

# %%
plt.scatter(tsne_x.T[0], tsne_x.T[1], c=cluster_x)

# %%
vectorizer.transform(['history']).todense()[0, 2766]
# Out:
# 1.0

# %%
vectorizer.transform(['test history']).todense()[0, 5211]
# Out:
# 0.9790968196364223

# %%
ann = anns[i]
lines = load_txt(ann)

entities = []
relations = []

for line in lines:
    cols = line.strip('\n').strip('\t').split('\t')
    if len(cols) == 2:
        try:
            terms = cols[1].split(' ')
            label = terms[0]
            rel1 = terms[1]
            rel2 = terms[2]
            relations.append({
                'id': cols[0],
                'label': label,
                'rel1': rel1,
                'rel2': rel2
            })
        except:
            #skip rows that have unknown formatting
            pass
        
    else:
        try:
            terms = cols[1].split(' ')
            label = terms[0]
            start = terms[1]
            stop = terms[2]
            entities.append({
                'id': cols[0],
                'label': label,
                'start': start,
                'stop': stop,
                'value': cols[2]
            })
        except:
            #skip rows that have unknown formatting
            pass


    idx = line.split('\t')[0]
    line = line.split('\t')

entities = pd.DataFrame(entities).set_index('id')
relations = pd.DataFrame(relations).set_index('id')

if lower:
    entities['value'] = entities['value'].str.lower()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25464/2630029285.py in <module>
#      47 relations = pd.DataFrame(relations).set_index('id')
#      48
# ---> 49 if lower:
#      50     entities['value'] = entities['value'].str.lower()
#
# NameError: name 'lower' is not defined

# %%
def get_entities_relations(patient_id=None, i=None, lower=True):
    '''
    Read .ann file and convert to dataframe of entities and relations
    '''
    if patient_id is not None:
        ann = patient_id + '.ann'
    elif i is not None:
        ann = anns[i]
    lines = load_txt(ann)

    entities = []
    relations = []

    for line in lines:
        cols = line.strip('\n').strip('\t').split('\t')
        if len(cols) == 2:
            try:
                terms = cols[1].split(' ')
                label = terms[0]
                rel1 = terms[1]
                rel2 = terms[2]
                relations.append({
                    'id': cols[0],
                    'label': label,
                    'rel1': rel1,
                    'rel2': rel2
                })
            except:
                #skip rows that have unknown formatting
                pass

        else:
            try:
                terms = cols[1].split(' ')
                label = terms[0]
                start = terms[1]
                stop = terms[2]
                entities.append({
                    'id': cols[0],
                    'label': label,
                    'start': start,
                    'stop': stop,
                    'value': cols[2]
                })
            except:
                #skip rows that have unknown formatting
                pass


        idx = line.split('\t')[0]
        line = line.split('\t')

    entities = pd.DataFrame(entities).set_index('id')
    relations = pd.DataFrame(relations).set_index('id')

    if lower:
        entities['value'] = entities['value'].str.lower()
    return entities, relations



def get_reason_drug(entities, relations):
    '''Pull Reason, Drug from entities, Reason-Drug from relations'''
    reasons = list(entities[entities['label'] == 'Reason']['value'])
    drugs = list(entities[entities['label'] == 'Drug']['value'])
    reason_drug = relations[relations['label'] == 'Reason-Drug']
    
    return reasons, drugs, reason_drug
    
def get_reason_drug_pairs(entities, reason_drug):
    '''Get references from Reason-Drug relations and turn into
    tuples of reason and drug'''
    reason_drug_pairs = []
    for row in reason_drug.iterrows():
        id1 = row[1]['rel1'].split('Arg1:')[1]
        id2 = row[1]['rel2'].split('Arg2:')[1]


        reason = entities.loc[id1, 'value']
        drug = entities.loc[id2, 'value']

        reason_drug_pairs.append((reason, drug))
    return reason_drug_pairs


def convert_to_lines(reasons, drugs, reason_drug_pairs):
    '''
    Convert reasons and drugs into lines
    '''
    reasons = [(' <reas> ' + reason)
                   for reason in reasons]
    drugs = [(' <drug> ' + drug) 
                 for drug in drugs]
    pairs = [(' <pair> ' + reason + ' <sep> ' + drug) 
                 for reason, drug in reason_drug_pairs]

    return reasons, drugs, pairs


# def mask_reason_drug_pairs(reason_drug_pairs):

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordLevel
from tokenizers.trainers import WordLevelTrainer
from tokenizers.pre_tokenizers import Whitespace

# %%
# Build tokenizer corpus from all_reason_drug_pairs
all_reason_drug_pairs = []
for i in tqdm(range(len(anns))):
    entities, relations = get_entities_relations(i=i)
    reasons, drugs, reason_drug = get_reason_drug(entities, relations)
    reason_drug_pairs = get_reason_drug_pairs(entities, reason_drug)
    reasons, drugs, reason_drug_pairs = \
        convert_to_lines(reasons, drugs, reason_drug_pairs)
    
    all_reason_drug_pairs += reason_drug_pairs

tokenizer = Tokenizer(WordLevel(unk_token='<unk>'))

trainer = WordLevelTrainer(special_tokens=['<unk>', '<reas>', '<drug>', '<pair>',
                                           '<sep>', '<mask>', '<s>', '</s>'])
tokenizer.pre_tokenizer = Whitespace()
tokenizer.train_from_iterator(all_reason_drug_pairs, trainer=trainer)

tokenizer.enable_truncation(max_length=512) 
#only 18 cases that end up larger than 512
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 303/303 [00:02<00:00, 130.94it/s]

# %%
# Convert lines with reasons, drugs, and reason-drug pairs to tokens

training_lines = []
for i in tqdm(range(len(anns))):
    entities, relations = get_entities_relations(i=i)
    reasons, drugs, reason_drug = get_reason_drug(entities, relations)
    reason_drug_pairs = get_reason_drug_pairs(entities, reason_drug)
    reasons, drugs, reason_drug_pairs = \
        convert_to_lines(reasons, drugs, reason_drug_pairs)
    
    encoded_line = tokenizer.encode('<s>' +
        ''.join(reasons) + ' ' + ''.join(drugs) + 
        ' ' + ''.join(reason_drug_pairs) + '</s>')
    training_lines.append(encoded_line)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 303/303 [00:02<00:00, 123.09it/s]

# %%
def get_batch_pair_mlm(batch_size=16, starting_idx=0):
    MASK_TOKEN = 5
    PAIR_TOKEN = 3
    
    lines = training_lines[starting_idx:starting_idx+batch_size]
    tensor_lines = []
    # masking
    for line in lines:
        # Mask 15% of elements from the reason-drug pair
        # section which are not special tokens
        line = torch.tensor(line.ids)
        pair_mask = torch.zeros(len(line))
        pair_start = torch.argmax((line == PAIR_TOKEN)*1)
        pair_mask[pair_start+1:] = 1
        
        mask_arr = ((torch.rand(len(line)) < 0.15)*1) * ((line > 7)*1)
        
        masks = pair_mask * mask_arr
        
        line[masks == 1] = MASK_TOKEN
        tensor_lines.append(line)
        
        
    # padding
    padding_len = 0
    for line in lines:
        padding_len = max(padding_len, len(line))
    return tensor_lines, masks

# %%
import torch

# %%
mask_arr = torch.rand(len(lines[0])) < 0.15
pair_mask = torch.zeros(len(lines[0]))
pair_start = np.argmax(np.array(lines[0].ids) == 3)
pair_mask[pair_start+1:] = 1

# %%
masks = (pair_mask == 1) & mask_arr

# %%
line = torch.tensor(lines[0].ids)

# %%
len(line)
# Out:
# 460

# %%
from transformers import RobertaConfig
from transformers import RobertaForMaskedLM

# %%
# Out:
# 2446

# %%
config = RobertaConfig(vocab_size=tokenizer.get_vocab_size(),
                       max_position_embeddings=514,
                       num_attention_heads=3,
                       num_hidden_layers=2,
                       type_vocab_size=1,
                      )
model = RobertaForMaskedLM(config=config)

# %%
model.eval()
# Out:
# RobertaForMaskedLM(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(2446, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (lm_head): RobertaLMHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (decoder): Linear(in_features=768, out_features=2446, bias=True)
#   )
# )

# %%
encoding = tokenizer.encode(reason_drug_pairs[0])
encoding.pad(50)

# %%
len(encoding)
# Out:
# 50

# %%
for line in reason_drug_pairs:
    for word in line:
        if np.random.rand() < 0.15:
            #randomize
# Out:
# [['<pair>', 'recurrent', 'seizures', '<sep>', 'ativan'],
#  ['<pair>', 'agitation', '<sep>', 'sedation'],
#  ['<pair>', 'agitation', '<sep>', 'seroquel'],
#  ['<pair>', 'agitation', '<sep>', 'seroquel'],
#  ['<pair>', 'asthma', '<sep>', 'albuterol'],
#  ['<pair>', 'asthma', '<sep>', 'ipratriopium'],
#  ['<pair>', 'asthma', '<sep>', 'prednisone'],
#  ['<pair>', 'asthma', '<sep>', 'advair'],
#  ['<pair>', 'wheezing', '<sep>', 'advair'],
#  ['<pair>', 'ventilator', 'associated', 'pneumonia', '<sep>', 'vanc'],
#  ['<pair>', 'ventilator', 'associated', 'pneumonia', '<sep>', 'cefepime'],
#  ['<pair>', 'ventilator', 'associated', 'pneumonia', '<sep>', 'cipro'],
#  ['<pair>', 'asthma', '<sep>', 'epi'],
#  ['<pair>', 'diuresed', '<sep>', 'lasix'],
#  ['<pair>', 'elevated', 'cr', '1', '.', '9', '<sep>', 'ace'],
#  ['<pair>', 'low', 'bps', '<sep>', 'ace'],
#  ['<pair>', 'hypertension', '<sep>', 'lisinopril'],
#  ['<pair>', 'pain', '<sep>', 'ultram'],
#  ['<pair>', 'pain', '<sep>', 'tylenol'],
#  ['<pair>', 'pain', '<sep>', 'lidocaine'],
#  ['<pair>', 'pain', '<sep>', 'calcitonin'],
#  ['<pair>', 'cap', '<sep>', 'ctx'],
#  ['<pair>', 'cap', '<sep>', 'azithromycin'],
#  ['<pair>', 'cap', '<sep>', 'azithromycin'],
#  ['<pair>', 'asthma', '<sep>', 'ctx'],
#  ['<pair>', 'asthma', '<sep>', 'azithromycin'],
#  ['<pair>', 'asthma', '<sep>', 'azithromycin'],
#  ['<pair>', 'constipation', '<sep>', 'bisacodyl'],
#  ['<pair>', 'constipation', '<sep>', 'bisacodyl'],
#  ['<pair>', 'constipation', '<sep>', 'senna'],
#  ['<pair>', 'pain', '<sep>', 'acetaminophen'],
#  ['<pair>', 'fever', '<sep>', 'acetaminophen'],
#  ['<pair>', 'sleep', '<sep>', 'olanzapine'],
#  ['<pair>', 'sob', '<sep>', 'albuterol', 'sulfate'],
#  ['<pair>', 'sob', '<sep>', 'albuterol', 'sulfate'],
#  ['<pair>', 'back', 'pain', '<sep>', 'tramadol'],
#  ['<pair>', 'back', 'pain', '<sep>', 'tramadol'],
#  ['<pair>', 'seizure', '<sep>', 'lorazepam'],
#  ['<pair>', 'longer', 'than', '5', 'minutes', '<sep>', 'lorazepam'],
#  ['<pair>', 'seizures', '<sep>', 's', 'eizure', 'medications'],
#  ['<pair>', 'grand', 'mal', 'seizure', '<sep>', 'keppra'],
#  ['<pair>', 'aggitated', '<sep>', 'topiramate'],
#  ['<pair>', 'grand', 'mal', 'seizure', '<sep>', 'ativan'],
#  ['<pair>', 'pain', '<sep>', 'acetaminophen'],
#  ['<pair>', 'fever', '<sep>', 'acetaminophen']]

# %%
entities, relations = get_entities_relations(i=0)
reasons, drugs, reason_drug = get_reason_drug(entities, relations)
reason_drug_pairs = get_reason_drug_pairs(entities, reason_drug)
reasons, drugs, reason_drug_pairs = \
    convert_to_tokens(reasons, drugs, reason_drug_pairs)

# %%
from torchtext.vocab import build_vocab_from_iterator
from torchtext.data.utils import get_tokenizer

# %%
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 303/303 [00:02<00:00, 126.19it/s]

# %%
all_reason_drug_pairs
# Out:
# [' <pair> recurrent seizures <sep> ativan',
#  ' <pair> agitation <sep> sedation',
#  ' <pair> agitation <sep> seroquel',
#  ' <pair> agitation <sep> seroquel',
#  ' <pair> asthma <sep> albuterol',
#  ' <pair> asthma <sep> ipratriopium',
#  ' <pair> asthma <sep> prednisone',
#  ' <pair> asthma <sep> advair',
#  ' <pair> wheezing <sep> advair',
#  ' <pair> ventilator associated pneumonia <sep> vanc',
#  ' <pair> ventilator associated pneumonia <sep> cefepime',
#  ' <pair> ventilator associated pneumonia <sep> cipro',
#  ' <pair> asthma <sep> epi',
#  ' <pair> diuresed <sep> lasix',
#  ' <pair> elevated cr 1.9 <sep> ace',
#  ' <pair> low bps <sep> ace',
#  ' <pair> hypertension <sep> lisinopril',
#  ' <pair> pain <sep> ultram',
#  ' <pair> pain <sep> tylenol',
#  ' <pair> pain <sep> lidocaine',
#  ' <pair> pain <sep> calcitonin',
#  ' <pair> cap <sep> ctx',
#  ' <pair> cap <sep> azithromycin',
#  ' <pair> cap <sep> azithromycin',
#  ' <pair> asthma <sep> ctx',
#  ' <pair> asthma <sep> azithromycin',
#  ' <pair> asthma <sep> azithromycin',
#  ' <pair> constipation <sep> bisacodyl',
#  ' <pair> constipation <sep> bisacodyl',
#  ' <pair> constipation <sep> senna',
#  ' <pair> pain <sep> acetaminophen',
#  ' <pair> fever <sep> acetaminophen',
#  ' <pair> sleep <sep> olanzapine',
#  ' <pair> sob <sep> albuterol sulfate',
#  ' <pair> sob <sep> albuterol sulfate',
#  ' <pair> back pain <sep> tramadol',
#  ' <pair> back pain <sep> tramadol',
#  ' <pair> seizure <sep> lorazepam',
#  ' <pair> longer than 5 minutes <sep> lorazepam',
#  ' <pair> seizures <sep> s eizure medications',
#  ' <pair> grand mal seizure <sep> keppra',
#  ' <pair> aggitated <sep> topiramate',
#  ' <pair> grand mal seizure <sep> ativan',
#  ' <pair> pain <sep> acetaminophen',
#  ' <pair> fever <sep> acetaminophen',
#  ' <pair> antispasmodic effect <sep> bentyl',
#  ' <pair> peripheral edema <sep> lasix',
#  ' <pair> gvhd <sep> solumedrol',
#  ' <pair> gvhd <sep> cellcept',
#  ' <pair> diuresis <sep> torsemide',
#  ' <pair> tachycardia <sep> beta blocker',
#  ' <pair> gvhd <sep> cellcept',
#  ' <pair> gvhd <sep> prednisone',
#  ' <pair> diuresis <sep> milrinone',
#  ' <pair> diuresis <sep> lasix',
#  ' <pair> diuresed <sep> milrinone',
#  ' <pair> diuresed <sep> lasix',
#  ' <pair> all <sep> daunorubicin',
#  ' <pair> all <sep> vincristine',
#  ' <pair> all <sep> dexamethasone',
#  ' <pair> all <sep> l-asparaginase',
#  ' <pair> all <sep> mtx',
#  ' <pair> all <sep> cyclophosphamide',
#  ' <pair> all <sep> cytarabine',
#  ' <pair> all <sep> mercaptopurine',
#  ' <pair> all <sep> mtx',
#  ' <pair> therapeutic inr <sep> heparin',
#  ' <pair> pain <sep> morphine',
#  ' <pair> nausea <sep> lorazepam',
#  ' <pair> nausea <sep> lorazepam',
#  ' <pair> sob <sep> albuterol sulfate',
#  ' <pair> wheeze <sep> albuterol sulfate',
#  ' <pair> nausea <sep> zofran',
#  ' <pair> abdominal pain <sep> simethicone',
#  ' <pair> gas <sep> simethicone',
#  ' <pair> constipation <sep> magnesium hydroxide',
#  ' <pair> embolic stroke <sep> coumadin',
#  ' <pair> leukemia <sep> steroids',
#  ' <pair> leukemia <sep> mycophenolate mofetil',
#  ' <pair> abdominal pain <sep> bentyl',
#  ' <pair> prevent infection <sep> bactrim',
#  ' <pair> prevent infection <sep> acyclovir',
#  ' <pair> uric acid levels were high <sep> allopurinol',
#  ' <pair> pain <sep> morphine',
#  ' <pair> abdominal pain <sep> dicyclomine',
#  ' <pair> gas <sep> simethicone',
#  ' <pair> ascites <sep> lasix',
#  ' <pair> hematoma <sep> prbcs',
#  ' <pair> hematoma <sep> ffp',
#  ' <pair> zoster <sep> acyclovir',
#  ' <pair> candidal vaginitis <sep> fluconazole',
#  ' <pair> hyperlipidemia <sep> lipitor',
#  ' <pair> depression <sep> prozac',
#  ' <pair> depression <sep> risperdone',
#  ' <pair> depression <sep> wellbutrin',
#  ' <pair> depression <sep> klonopin',
#  ' <pair> sad <sep> wellbutrin',
#  ' <pair> sad <sep> risperdone',
#  ' <pair> sad <sep> prozac',
#  ' <pair> sad <sep> klonopin',
#  ' <pair> ulcerative colitis <sep> mesalamine',
#  ' <pair> orthostatic hypotension <sep> midodrine',
#  ' <pair> anxiety <sep> clonazepam',
#  ' <pair> constipation <sep> bisacodyl',
#  ' <pair> pain <sep> oxycodone',
#  ' <pair> wheezing <sep> albuterol sulfate',
#  ' <pair> pain <sep> acetaminophen',
#  ' <pair> hematoma <sep> prbcs',
#  ' <pair> pneumonia <sep> vanco',
#  ' <pair> pneumonia <sep> flagyl',
#  ' <pair> pneumonia <sep> levo',
#  ' <pair> pneumonia <sep> levofloxacin',
#  ' <pair> pneumonia <sep> vancomycin',
#  ' <pair> pneumonia <sep> levofloxacin',
#  ' <pair> mrsa <sep> vancomycin',
#  ' <pair> mrsa <sep> vancomycin',
#  ' <pair> aspiration pna <sep> levo',
#  ' <pair> aspiration pna <sep> flagyl',
#  ' <pair> pseudomonas <sep> meropenem',
#  ' <pair> breaking up thick sputum <sep> mucomyst',
#  ' <pair> pulmonary embolism <sep> coumadin',
#  ' <pair> pulmonary embolism <sep> lovenox',
#  ' <pair> pulmonary embolism <sep> lovenox',
#  ' <pair> dvts <sep> coumadin',
#  ' <pair> anticoagulation <sep> lovenox',
#  ' <pair> multifocal pneumonia <sep> levofloxacin',
#  ' <pair> multifocal pneumonia <sep> vancomycin',
#  ' <pair> renal transplant <sep> cyclosporine',
#  ' <pair> renal transplant <sep> prednisone',
#  ' <pair> atrial fibrillation <sep> coumadin',
#  ' <pair> elevated pth <sep> sensipar',
#  ' <pair> renal transplant <sep> prednisone',
#  ' <pair> infection <sep> vanco',
#  ' <pair> infection <sep> flagyl',
#  ' <pair> infection <sep> zosyn',
#  ' <pair> adrenal insufficiency <sep> decadron',
#  ' <pair> abdominal pain <sep> oxycodone',
#  ' <pair> hyperkalemia <sep> calcium gluconate',
#  ' <pair> hyperkalemia <sep> sodium bicarbonate',
#  ' <pair> hyperkalemia <sep> insulin',
#  ' <pair> hyperkalemia <sep> d50',
#  ' <pair> to control phosphorus because of kidney failure <sep> fosrenal',
#  ' <pair> to control calcium and phosphorus because of kidney failure <sep> cinecalcet',
#  ' <pair> to protect your stomach when taking prednisone <sep> protonix',
#  ' <pair> af <sep> coumadin',
#  ' <pair> your heart rate <sep> captopril',
#  ' <pair> dmii <sep> glyburide',
#  ' <pair> rectal ca <sep> 5- fu',
#  ' <pair> peri-catheter thrombus <sep> tpa',
#  ' <pair> thrombolysis <sep> tpa',
#  ' <pair> rectal ca <sep> 5-fu',
#  ' <pair> rectal ca <sep> xeloda',
#  ' <pair> dmii <sep> glyburide',
#  ' <pair> pain <sep> oxycodone',
#  ' <pair> constipation <sep> senna',
#  ' <pair> dyspnea <sep> albuterol sulfate',
#  ' <pair> wheeze <sep> albuterol sulfate',
#  ' <pair> pain <sep> acetaminophen',
#  ' <pair> itching <sep> camphor-menthol',
#  ' <pair> apply to groin <sep> miconazole nitrate',
#  ' <pair> dryness <sep> white petrolatum-mineral oil',
#  ' <pair> mucus <sep> acetylcysteine',
#  ' <pair> volume overload <sep> lasix',
#  ' <pair> line flush <sep> heparin flush',
#  ' <pair> insomina <sep> trazodone',
#  ' <pair> pain <sep> oxycodone-acetaminophen',
#  ' <pair> cramping <sep> oxycodone-acetaminophen',
#  ' <pair> atrial fibrillation <sep> coumadin',
#  ' <pair> pneumonia <sep> antibiotics',
#  ' <pair> pneumonia <sep> tobramycin',
#  ' <pair> staph <sep> vancomycin',
#  ' <pair> staph <sep> zosyn',
#  ' <pair> gerd <sep> ranitidine',
#  ' <pair> insomnia <sep> temazepam',
#  ' <pair> shortness of breath <sep> albuterol sulfate',
#  ' <pair> wheezing <sep> albuterol sulfate',
#  ' <pair> fever <sep> tylenol',
#  ' <pair> presumed pna versus cellulitis <sep> vanc/ctx',
#  ' <pair> line flush <sep> heparin flush',
#  ' <pair> chest pain <sep> nitroglycerin',
#  ' <pair> anxiety <sep> lorazepam',
#  ' <pair> constipation <sep> lactulose',
#  ' <pair> constipation <sep> polyethylene glycol',
#  ' <pair> constipation <sep> senna',
#  ' <pair> sob <sep> albuterol sulfate',
#  ' <pair> wheeze <sep> albuterol sulfate',
#  ' <pair> sob <sep> albuterol sulfate',
#  ' <pair> sob <sep> ipratropium bromide',
#  ' <pair> wheeze <sep> ipratropium bromide',
#  ' <pair> pain <sep> oxycodone-acetaminophen',
#  ' <pair> chest pain <sep> nitroglycerin',
#  ' <pair> anxiety <sep> lorazepam',
#  ' <pair> constipation <sep> lactulose',
#  ' <pair> constipation <sep> polyethylene glycol 3350',
#  ' <pair> anxiety <sep> ativan',
#  ' <pair> anxiety <sep> percocet',
#  ' <pair> constipation <sep> senna',
#  ' <pair> low back pain <sep> ativan',
#  ' <pair> low back pain <sep> percocet',
#  ' <pair> dyspnea <sep> albuterol sulfate',
#  ' <pair> sob <sep> ipratropium bromide',
#  ' <pair> back pain <sep> lidocaine',
#  ' <pair> anxiety <sep> lorazepam',
#  ' <pair> wheezing <sep> albuterol',
#  ' <pair> back pain <sep> lidoderm',
#  ' <pair> narcotic induced respiratory distress <sep> naloxone',
#  ' <pair> copd exacerbation <sep> albuterol/ipratropium',
#  ' <pair> anxiety <sep> haloperidol',
#  ' <pair> anxiety <sep> clonopin',
#  ' <pair> agitation <sep> clonopin',
#  ' <pair> agitation <sep> haloperidol',
#  ' <pair> pain control <sep> tylenol',
#  ' <pair> pain control <sep> lidoderm',
#  ' <pair> anxiety <sep> haldol',
#  ' <pair> anxiety <sep> klonopin',
#  ' <pair> severe copd <sep> oxygen',
#  ' <pair> agitated <sep> haldol',
#  ' <pair> copd exacerbation <sep> solumedrol',
#  ' <pair> copd exacerbation <sep> ceftriaxone',
#  ' <pair> copd exacerbation <sep> azithromycin',
#  ' <pair> rate control <sep> beta blocker',
#  ' <pair> gastric or pancreatico/biliary tumor <sep> gemcitabine',
#  ' <pair> gastric or pancreatico/biliary tumor <sep> irinotecan',
#  ' <pair> metastatic adenocarcinoma <sep> gemcitabine',
#  ' <pair> metastatic adenocarcinoma <sep> irinotecan',
#  ' <pair> edema <sep> lasix',
#  ' <pair> edema <sep> oxygen',
#  ' <pair> metastatic disease <sep> cpt-11',
#  ' <pair> metastatic disease <sep> gemzar',
#  ' <pair> diarrhea <sep> lomotil',
#  ' <pair> dvt <sep> lovenox',
#  ' <pair> r flank pain <sep> fentanyl',
#  ' <pair> pain control <sep> fentanyl',
#  ' <pair> breakthrough pain <sep> morphine',
#  ' <pair> breakthrough pain <sep> lidocaine',
#  ' <pair> pain <sep> ibuprofen',
#  ' <pair> nausea <sep> zofran',
#  ' <pair> nausea <sep> lorazepam',
#  ' <pair> constipation <sep> senna',
#  ' <pair> diarrhea <sep> lomotil',
#  ' <pair> gastric or pancreatico/biliary tumor <sep> chemotherapy',
#  ' <pair> metastatic disease <sep> chemotherapy',
#  ' <pair> pe <sep> lovenox',
#  ' <pair> foot ulcer <sep> cipro',
#  ' <pair> foot ulcer <sep> meropenum',
#  ' <pair> foot ulcer <sep> gent',
#  ' <pair> foot ulcer <sep> ceftriaxone',
#  ' <pair> foot ulcer <sep> zosyn',
#  ' <pair> foot ulcer <sep> amp/sublactam',
#  ' <pair> foot ulcer <sep> vanc',
#  ' <pair> foot ulcer <sep> zosyn',
#  ' <pair> foot ulcer <sep> cipro',
#  ' <pair> foot ulcer <sep> keflex',
#  ' <pair> diabetic ketoacidosis <sep> insulin',
#  ' <pair> diabetic ketoacidosis <sep> fluid',
#  ' <pair> diabetic ketoacidosis <sep> inslin',
#  ' <pair> increasing glucose levels <sep> humalog',
#  ' <pair> anemia <sep> ferrous sulfate',
#  ' <pair> iron supplementation <sep> ferrous sulfate',
#  ' <pair> skin lesions <sep> hydroxyzine',
#  ' <pair> skin lesions <sep> sarna',
#  ' <pair> rash <sep> clobetasol',
#  ' <pair> pruritis <sep> camphor-menthol',
#  ' <pair> diabetic ketoacidosis <sep> insulin',
#  ' <pair> diabetic ketoacidosis <sep> fluid',
#  ' <pair> diabetic ketoacidosis <sep> insulin',
#  ' <pair> diabetic ketoacidosis <sep> fluids',
#  ' <pair> foot infection <sep> vancomycin',
#  ' <pair> foot infection <sep> tazobactam',
#  ' <pair> foot infection <sep> piperacillin',
#  ' <pair> foot infection <sep> antibiotics',
#  ' <pair> cellulitis <sep> vancomycin',
#  ' <pair> abscess <sep> antibiotics',
#  ' <pair> abscess <sep> fluid',
#  ' <pair> abscess <sep> percocet',
#  ' <pair> cellulitis <sep> antibiotics',
#  ' <pair> cellulitis <sep> vancomycin',
#  ' <pair> cellulitis <sep> antibiotics',
#  ' <pair> drug reaction <sep> antibiotics',
#  ' <pair> low blood pressure <sep> dopamine',
#  ' <pair> hypotension <sep> dopamine',
#  ' <pair> chronic obstructive pulmonary disease <sep> oxygen',
#  ' <pair> respiratory distress <sep> steroids',
#  ' <pair> hypertension <sep> metoprolol',
#  ' <pair> hypertension <sep> ace inhibitor',
#  ' <pair> coronary artery disease <sep> aspirin',
#  ' <pair> coronary artery disease <sep> lipitor',
#  ' <pair> renal failure <sep> fluids',
#  ' <pair> prophylaxis <sep> proton pump inhibitors',
#  ' <pair> prophylaxis <sep> heparin',
#  ' <pair> hypotension <sep> pressors',
#  ' <pair> hypotension <sep> levophed',
#  ' <pair> hypotension <sep> dopamine',
#  ' <pair> carbapenemase-resistant e.coli <sep> nitrofurantoin',
#  ' <pair> carbapenemase-resistant e.coli <sep> amikacin',
#  ' <pair> hepatorenal syndrome <sep> octreotride',
#  ' <pair> hepatorenal syndrome <sep> midodrine',
#  ' <pair> hepatorenal syndrome <sep> albumin',
#  ' <pair> dic <sep> fresh frozen plasma',
#  ' <pair> dic <sep> cryoprecipitate',
#  ' <pair> dic <sep> platelets',
#  ' <pair> dic <sep> red blood cells',
#  ' <pair> finger stick was 50 <sep> d50',
#  ' <pair> combative <sep> haldol',
#  ' <pair> hepatic encephalopathy <sep> lactulose',
#  ' <pair> hepatic encephalopathy <sep> rifaximin',
#  ' <pair> carbapenemase-resistant e.coli <sep> tetracycline',
#  ' <pair> carbapenemase-resistant e.coli <sep> colistin',
#  ' <pair> screaming <sep> haldol',
#  ' <pair> sedation <sep> midazolam',
#  ' <pair> sedation <sep> fentanyl',
#  ' <pair> uti <sep> levofloxacin',
#  ' <pair> aspiration pneumonia <sep> vancomycin',
#  ' <pair> aspiration pneumonia <sep> metronidazole',
#  ' <pair> aspiration pneumonia <sep> levofloxacin',
#  ' <pair> pulmonary emboli <sep> coumadin',
#  ' <pair> pulmonary emboli <sep> coumadin',
#  ' <pair> high risk for thromboembolism <sep> lovenox',
#  ' <pair> schizophrenia <sep> depakote',
#  ' <pair> schizophrenia <sep> risperdal',
#  ' <pair> schizophrenia <sep> remeron',
#  ' <pair> pneumonia, mrsa <sep> vanc',
#  ' <pair> pneumonia, mrsa <sep> zosyn',
#  ' <pair> hypothyroidism <sep> levothyroxine',
#  ' <pair> hypothyroidism <sep> levothyroxine',
#  ' <pair> inr<2 <sep> lovenox',
#  ' <pair> for low triiodothyronine thyroxine (t4) <sep> levothyroxine',
#  ' <pair> constipation <sep> milk of magnesia',
#  ' <pair> constipation <sep> bisacodyl',
#  ' <pair> loose stools <sep> loperamide',
#  ' <pair> anxiety <sep> lorazepam',
#  ' <pair> wheezing <sep> duoneb',
#  ' <pair> wheezing <sep> ipratropium-albuterol',
#  ' <pair> constipation <sep> bisacodyl',
#  ' <pair> constipation <sep> milk of magnesia',
#  ' <pair> loose stools <sep> loperamide',
#  ' <pair> anxiety <sep> lorazepam',
#  ' <pair> pain <sep> hydrocodone-acetaminophen',
#  ' <pair> wheezing <sep> duoneb',
#  ' <pair> wheezing <sep> ipratropium-albuterol',
#  ' <pair> pneumonia <sep> antibiotics',
#  ' <pair> lung clots <sep> coumadin',
#  ' <pair> pneumonia <sep> z-pack',
#  ' <pair> pain <sep> hydrocodone-acetaminophen',
#  ' <pair> blood clots) <sep> coumadin',
#  ' <pair> extremity erythema and itching <sep> benadryl',
#  ' <pair> fever <sep> tylenol',
#  ' <pair> stage i breast cancer <sep> tamoxifen',
#  ' <pair> breast ca <sep> tamoxifen',
#  ' <pair> healthcare-associated pneumonia <sep> antibiotics',
#  ' <pair> resuscitation <sep> fluid',
#  ' <pair> hypotensive <sep> vasopressors',
#  ' <pair> hypertensive <sep> labetolol',
#  ' <pair> ventilator associated pneumonia <sep> antibiotics',
#  ' <pair> positive blood cultures <sep> antibiotics',
#  ' <pair> adequate blood pressure control <sep> labetolol',
#  ' <pair> spiked to 101.3 <sep> flagyl',
#  ' <pair> spiked to 101.3 <sep> cefepime',
#  ' <pair> spiked to 101.3 <sep> vanco',
#  ' <pair> rectal metastatic adenocarcinoma <sep> avastin',
#  ' <pair> rectal metastatic adenocarcinoma <sep> 5fu',
#  ' <pair> rectal metastatic adenocarcinoma <sep> leucovorin',
#  ' <pair> diarrhea <sep> cefepime',
#  ' <pair> diarrhea <sep> lomotil',
#  ' <pair> diarrhea <sep> metronidazole',
#  ' <pair> diarrhea <sep> vancomycin',
#  ' <pair> fevers <sep> cefepime',
#  ' <pair> fevers <sep> metronidazole',
#  ' <pair> fevers <sep> vancomycin',
#  ' <pair> acidosis <sep> ivf',
#  ' <pair> acidosis <sep> bicarb',
#  ' <pair> dropping hct <sep> prbcs',
#  ' <pair> elevated inr <sep> ffp',
#  ' <pair> neutropenic fever <sep> cefepime',
#  ' <pair> neutropenic fever <sep> vancomycin',
#  ' <pair> neutropenic fever <sep> flagyl',
#  ' <pair> diarrhea <sep> lomotil',
#  ' <pair> relieve obstruction <sep> octreotide',
#  ' <pair> neutropenic fever <sep> vanco',
#  ' <pair> neutropenic fever <sep> cefepime',
#  ' <pair> neutropenic fever <sep> flagyl',
#  ' <pair> aspiration/pneumonia <sep> antibiotics',
#  ' <pair> rectal cancer <sep> chemotherapy',
#  ' <pair> rectal cancer <sep> 5fu',
#  ' <pair> rectal cancer <sep> avastin',
#  ' <pair> rectal cancer <sep> chemotherapy',
#  ' <pair> sbo <sep> ivf',
#  ' <pair> sbo <sep> ivf',
#  ' <pair> primary hypothyroidism <sep> synthroid',
#  ' <pair> primary hypothyroidism <sep> synthroid',
#  ' <pair> hypothyroidism <sep> synthroid',
#  ' <pair> hypothyroidism <sep> synthroid',
#  ' <pair> pancytopenia <sep> epogen',
#  ' <pair> anemia <sep> prbcs',
#  ' <pair> sepsis <sep> vanc',
#  ' <pair> sepsis <sep> levaquin',
#  ' <pair> dm2 <sep> glyburide',
#  ' <pair> dm2 <sep> insulin',
#  ' <pair> dm2 <sep> glyburide',
#  ' <pair> dm2 <sep> glipizide',
#  ' <pair> hyponatremic <sep> d5w',
#  ' <pair> cad <sep> bb',
#  ' <pair> cad <sep> beta blocker',
#  ' <pair> chf <sep> lasix',
#  ' <pair> overdry <sep> ns',
#  ' <pair> lll pna <sep> levaquin',
#  ' <pair> htn <sep> prazosin',
#  ' <pair> htn <sep> prasozin',
#  ' <pair> htn <sep> hydralazine',
#  ' <pair> cad <sep> statin',
#  ' <pair> cad <sep> asa',
#  ' <pair> sedation <sep> propofol',
#  ' <pair> pleuritic chest pain <sep> ibuprofen',
#  ' <pair> pleuritic chest pain <sep> tylenol',
#  ' <pair> pleuritic chest pain <sep> oxycodone',
#  ' <pair> headaches <sep> oxycodone',
#  ' <pair> chest pain <sep> oxycodone',
#  ' <pair> sah <sep> aspirin',
#  ' <pair> mca aneurysm s/p coiling <sep> aspirin',
#  ' <pair> asthma <sep> albuterol',
#  ' <pair> schizoaffective disorder <sep> seroquel',
#  ' <pair> schizoaffective disorder <sep> gabapentin',
#  ' <pair> schizoaffective disorder <sep> trazodone',
#  ' <pair> schizoaffective disorder <sep> benzos',
#  ' <pair> migraines <sep> butalbital',
#  ' <pair> pain <sep> acetaminophen',
#  ' <pair> pain <sep> oxycodone-acetaminophen',
#  ' <pair> anxiety <sep> lorazepam',
#  ' <pair> wheeze <sep> albuterol sulfate',
#  ' <pair> wheezing <sep> albuterol sulfate',
#  ' <pair> anxiety <sep> lorazepam',
#  ' <pair> pain <sep> acetaminophen',
#  ' <pair> pain <sep> ibuprofen',
#  ' <pair> adhd <sep> adderal',
#  ' <pair> fever <sep> acetaminophen',
#  ' <pair> back pain <sep> tylenol',
#  ' <pair> back pain <sep> ibuprofen',
#  ' <pair> back pain <sep> acetominophen',
#  ' <pair> back pain <sep> ibuprofen',
#  " <pair> presumed wernicke's <sep> thiamine",
#  ' <pair> agoraphobia <sep> sertraline',
#  ' <pair> opioid detox <sep> methadone',
#  ' <pair> hypertension <sep> lisinopril',
#  ' <pair> hypertension <sep> propranolol',
#  ' <pair> essential tremor <sep> proprnaolol',
#  ' <pair> cad <sep> aspirin',
#  ' <pair> bph <sep> tamsulosin',
#  ' <pair> gerd <sep> omeprazole',
#  ' <pair> agitation <sep> olanzapine',
#  ' <pair> psychosis <sep> olanzapine',
#  ' <pair> pain <sep> acetaminophen',
#  ' <pair> back pain <sep> ibuprofen',
#  ' <pair> stop the bleeding <sep> protamine',
#  ' <pair> chest pain radiating to the jaw <sep> aspirin',
#  ' <pair> chest pain radiating to the jaw <sep> plavix',
#  ' <pair> chest pain radiating to the jaw <sep> nitroglycerin',
#  ' <pair> chest pain radiating to the jaw <sep> nitroglycerin',
#  ' <pair> anaphylaxis <sep> solu- medrol',
#  ' <pair> anaphylaxis <sep> benadryl',
#  ' <pair> anaphylaxis <sep> pepcid',
#  ' <pair> anaphylaxis <sep> promethazine',
#  ' <pair> st elevations <sep> nitroglycerin',
#  ' <pair> anaphylactic reaction <sep> solu- medrol',
#  ' <pair> oa pain <sep> nsaid',
#  ' <pair> oa pain <sep> voltaren',
#  ' <pair> tachycardic <sep> ivf',
#  ' <pair> cratered 15mm ulcer <sep> epinephrine',
#  ' <pair> skin boil <sep> azithromycin',
#  ' <pair> aspiration pna <sep> gentamicin',
#  ' <pair> aspiration pna <sep> vanco',
#  ' <pair> aspiration pna <sep> flagyl',
#  ' <pair> hypotension <sep> dopamine',
#  ' <pair> hypotension <sep> ivf',
#  ' <pair> seizure d/o <sep> phenobarb',
#  ' <pair> seizure d/o <sep> diazepam',
#  ' <pair> diarrhea <sep> loperamide',
#  ' <pair> abd pain <sep> h2 blocker',
#  ' <pair> abd pain <sep> ppi',
#  ' <pair> tachycardia <sep> ivfs',
#  ' <pair> sbp dropped to the 80s and high 70s <sep> ivfs',
#  ' <pair> sbp dropped to the 80s and high 70s <sep> dopamine',
#  ' <pair> hypotension <sep> dopamine',
#  ' <pair> maintian maps>60 <sep> dopamine',
#  ' <pair> cdiff <sep> vanco',
#  ' <pair> cdiff <sep> gentamicin',
#  ' <pair> cdiff <sep> flagyl',
#  ' <pair> gerd <sep> ppi',
#  ' <pair> hypotensive <sep> pressors',
#  ' <pair> hypotensive <sep> ivf',
#  ' <pair> strep viridans line infection <sep> pcn g',
#  ' <pair> strep viridans line infection <sep> augmentin',
#  ' <pair> pain <sep> morphine',
#  ' <pair> pain <sep> morphine',
#  ' <pair> empiric meningitis coverage <sep> ceftriaxone',
#  ' <pair> empiric meningitis coverage <sep> vanco',
#  ' <pair> empiric meningitis coverage <sep> acyclovir',
#  ' <pair> lymphoblastic lymphoma <sep> r-chop',
#  ' <pair> lymphoblastic lymphoma <sep> r-chop',
#  ' <pair> lymphoblastic lymphoma <sep> vincristine',
#  ' <pair> lymphoblastic lymphoma <sep> rituximab',
#  ' <pair> lymphoblastic lymphoma <sep> prednisone',
#  ' <pair> all <sep> rituximab',
#  ' <pair> all <sep> prednisone',
#  ' <pair> acute lymphoblastic leukemia <sep> rituximab',
#  ' <pair> acute lymphoblastic leukemia <sep> rituximab',
#  ' <pair> acute lymphoblastic leukemia <sep> cyclophosphamide',
#  ' <pair> acute lymphoblastic leukemia <sep> dexamethasone',
#  ' <pair> acute lymphoblastic leukemia <sep> rituximab',
#  ' <pair> acute lymphoblastic leukemia <sep> prednisone',
#  ' <pair> acute lymphoblastic leukemia <sep> rituximab',
#  ' <pair> back pain <sep> morphine',
#  ' <pair> back pain <sep> methadone',
#  ' <pair> back pain <sep> methadone',
#  ' <pair> back pain <sep> morphine',
#  ' <pair> relapsing refractory all <sep> prednisone',
#  ' <pair> relapsing refractory all <sep> rituximab',
#  ' <pair> lymphoblastic lymphoma <sep> chemotherapy',
#  ' <pair> acute lymphoblastic leukemia <sep> chemotherapy',
#  ' <pair> lymphoma <sep> rituximab',
#  ' <pair> lgib <sep> prbc',
#  ' <pair> sedated <sep> fentanyl',
#  ' <pair> sedated <sep> propofol',
#  ' <pair> sedated <sep> dilaudid',
#  ' <pair> sedated <sep> oxycodone',
#  ' <pair> dystonia <sep> cogentin',
#  ' <pair> afib <sep> amiodarone',
#  ' <pair> afib <sep> amiodarone',
#  ' <pair> afib <sep> amiodarone',
#  ' <pair> afib <sep> lopressor',
#  ' <pair> afib <sep> amiodarone',
#  ' <pair> lower gi bleed <sep> rbc',
#  ' <pair> arf <sep> lasix',
#  ' <pair> pes <sep> argatroban',
#  ' <pair> pes <sep> argatroban',
#  ' <pair> pes <sep> coumadin',
#  ' <pair> pes <sep> coumadin',
#  ' <pair> hit <sep> argatroban',
#  ' <pair> hit <sep> argatroban',
#  ' <pair> hit <sep> coumadin',
#  ' <pair> hit <sep> coumadin',
#  ' <pair> mrsa pna <sep> vancomycin',
#  ' <pair> mrsa pna <sep> meropenem',
#  ' <pair> torulopsis <sep> fluconazole',
#  ' <pair> c. diff <sep> flagyl',
#  ' <pair> keep his sugars within a tight range <sep> insulin',
#  ' <pair> constipation <sep> maalox',
#  ' <pair> pain <sep> oxycodone',
#  ' <pair> pain <sep> acetaminophen',
#  ' <pair> fever <sep> acetaminophen',
#  ' <pair> atrial fibrillation <sep> amiodarone',
#  ' <pair> agitation <sep> oxazepam',
#  ' <pair> sbp prophylaxis <sep> levofloxacin',
#  ' <pair> encephalopathy <sep> rifaximin',
#  ' <pair> encephalopathy <sep> lactulose',
#  ' <pair> acute alcoholic hepatitis <sep> ursodiol',
#  ' <pair> acute alcoholic hepatitis <sep> pentoxyfilline',
#  ' <pair> hepatorenal syndrome <sep> midodrine',
#  ' <pair> hepatorenal syndrome <sep> octreotide',
#  ' <pair> volume repletion <sep> albumin',
#  ' <pair> volume repletion <sep> normal saline',
#  ' <pair> hct 25.9 <sep> prbc',
#  ' <pair> acute renal insufficiency <sep> midodrine',
#  ' <pair> acute renal insufficiency <sep> octreotide',
#  ' <pair> hepatorenal syndrome <sep> midodrine',
#  ' <pair> hepatorenal syndrome <sep> octreotide',
#  ' <pair> platelets of 37k <sep> platelets',
#  ' <pair> concern for infectious etiology <sep> levaquin',
#  ' <pair> concern for infectious etiology <sep> vancomycin',
#  ' <pair> concern for infectious etiology <sep> zosyn',
#  ' <pair> dm ii <sep> metformin',
#  ' <pair> dm ii <sep> insulin',
#  ' <pair> dm ii <sep> glargine',
#  ' <pair> dm ii <sep> glargine',
#  ' <pair> dm ii <sep> metformin',
#  ' <pair> sbp prophylaxis <sep> octreotide',
#  ' <pair> concern for infectious etiology <sep> antibiotics',
#  ' <pair> dm ii <sep> ssi',
#  ' <pair> dm ii <sep> hypoglycemics',
#  ' <pair> hypotensive <sep> vasopressors',
#  ' <pair> dvt prophylaxis <sep> heparin',
#  ' <pair> sedation <sep> benzodiazepines',
#  ' <pair> fevers <sep> atbx',
#  ' <pair> mouth pain <sep> maalox/diphenhydramine/lidocaine',
#  ' <pair> constipation <sep> docusate sodium',
#  ' <pair> sob <sep> albuterol-ipratropium',
#  ' <pair> wheezing <sep> albuterol-ipratropium',
#  ' <pair> constipation <sep> senna',
#  ' <pair> rash <sep> miconazole',
#  ' <pair> volume overload <sep> furosemide',
#  ' <pair> pneumonia <sep> antibiotics',
#  ' <pair> paroxysmal atrial fibrillation <sep> amiodarone',
#  ' <pair> constipation <sep> colace',
#  ' <pair> constipation <sep> senna',
#  ' <pair> mouth/throat pain <sep> maalox-diphenhydramine-lidocaine',
#  ' <pair> rash <sep> miconazole',
#  ' <pair> pneumonia <sep> antibiotics',
#  ' <pair> for coverage of severe cap <sep> levofloxacin',
#  ' <pair> biv pacer <sep> coumadin',
#  ' <pair> dmii <sep> insulin',
#  ' <pair> a-fib <sep> coumadin',
#  ' <pair> afib <sep> coumadin',
#  ' <pair> afib <sep> coumadin',
#  ' <pair> hd catheter infection <sep> vancomycin',
#  ' <pair> inr normalized <sep> vit k',
#  ' <pair> inr normalized <sep> ffp',
#  ' <pair> line infection <sep> vancomycin',
#  ' <pair> hypothyroidism <sep> levothyroxine',
#  ' <pair> systolic chf <sep> ffp',
#  ' <pair> systolic chf <sep> ivf',
#  ' <pair> diabetes type ii <sep> lantus',
#  ' <pair> diabetes type ii <sep> iss',
#  ' <pair> esrd <sep> vancomycin',
#  ' <pair> line infection <sep> vancomycin',
#  ' <pair> cad <sep> asa',
#  ' <pair> cad <sep> ace',
#  ' <pair> cad <sep> beta-blocker',
#  ' <pair> cad <sep> statin',
#  ' <pair> cad <sep> statin',
#  ' <pair> left phantom limb pain <sep> ultram',
#  ' <pair> wheeze <sep> albuterol',
#  ' <pair> pain <sep> percocet',
#  ' <pair> limb pain <sep> lidoderm',
#  ' <pair> constipation <sep> docusate sodium',
#  ' <pair> constipation <sep> senna',
#  ' <pair> pain <sep> acetaminophen',
#  ' <pair> pain <sep> acetaminophen',
#  ' <pair> insomnia <sep> zolpidem',
#  ' <pair> constipation <sep> bisacodyl',
#  ' <pair> severe constipation <sep> lactulose',
#  ' <pair> anxiety <sep> lorazepam',
#  ' <pair> pain <sep> oxycodone',
#  ' <pair> cough <sep> guaifenesin',
#  ' <pair> wheeze <sep> albuterol sulfate',
#  ' <pair> limb pain <sep> gabapentin',
#  ' <pair> supratherapeutic inr <sep> fresh frozen plasma',
#  ' <pair> supratherapeutic inr <sep> vitamin k',
#  ' <pair> left phantom limb pain <sep> lidocaine',
#  ' <pair> left phantom limb pain <sep> gabapentin',
#  ' <pair> left phantom limb pain <sep> gabapentin',
#  ' <pair> atrial fibrillation <sep> coumadin',
#  ' <pair> chronic anticoagulation <sep> coumadin',
#  ' <pair> polymyalgia rheumatica <sep> steroids',
#  ' <pair> afib <sep> coumadin',
#  ' <pair> gib <sep> ffp',
#  ' <pair> gib <sep> prbcs',
#  ' <pair> atrial fibrillation <sep> coumadin',
#  ' <pair> tia <sep> coumadin',
#  ' <pair> neutropenia <sep> levofloxacin',
#  ' <pair> a fib <sep> digoxin',
#  ' <pair> dementia <sep> namenda',
#  ' <pair> dementia <sep> aricept',
#  ' <pair> tia <sep> coumadin',
#  " <pair> tia's <sep> coumadin",
#  ' <pair> inr of 2.97 <sep> vitamin k',
#  ' <pair> parox af <sep> coumadin',
#  ' <pair> inr was corrected <sep> vitamin k',
#  ' <pair> inr was corrected <sep> profilnine',
#  ' <pair> inr was corrected <sep> ffp',
#  ' <pair> paroxysmal atrial fibrilation <sep> coumadin',
#  ' <pair> etoh withdrawal <sep> librium',
#  ' <pair> agitation <sep> ativan',
#  ' <pair> agitation <sep> ativan',
#  ' <pair> dm ii <sep> insulin',
#  ' <pair> pain <sep> acetaminophen',
#  ' <pair> rash <sep> miconazole nitrate',
#  ' <pair> constipation <sep> senna',
#  ' <pair> pain <sep> acetaminophen',
#  ' <pair> fungus <sep> miconazole nitrate',
#  ' <pair> constipation <sep> colace',
#  ' <pair> line flush <sep> heparin, porcine (pf)',
#  ' <pair> constipation <sep> colace',
#  ' <pair> tls <sep> allopurinol',
#  ' <pair> tls <sep> ivf',
#  ' <pair> worsening lactic acidosis <sep> bicarb',
#  ' <pair> pneumonia <sep> vanc',
#  ' <pair> pneumonia <sep> zosyn',
#  ' <pair> pneumonia <sep> azithro',
#  ' <pair> persistently elevated uric acid <sep> rasburicase',
#  ' <pair> renal failure <sep> rasburicase',
#  ' <pair> diuresed <sep> lasix',
#  ' <pair> mucositis <sep> pain medications',
#  ' <pair> pneumonia <sep> vanco',
#  ' <pair> pneumonia <sep> zosyn',
#  ' <pair> pneumonia <sep> azithro',
#  ' <pair> pneumonia <sep> vanco',
#  ' <pair> pneumonia <sep> zosyn',
#  ' <pair> pneumonia <sep> azithro',
#  ' <pair> pneumonia <sep> antibiotics',
#  ' <pair> rash <sep> triamcinolone',
#  ' <pair> contact dermatitis <sep> triamcinolone',
#  ' <pair> fluid retention <sep> lasix',
#  ' <pair> chemotherapy regimen <sep> fluids',
#  ' <pair> shingles <sep> lidocaine',
#  ' <pair> shingles <sep> oxycodone',
#  ' <pair> shingles <sep> oxycontin',
#  ' <pair> pain <sep> lidocaine',
#  ' <pair> pain <sep> oxycontin',
#  ' <pair> pain <sep> oxycodone',
#  ' <pair> bph <sep> finasteride',
#  ' <pair> bph <sep> tamsulosin',
#  ' <pair> constipation <sep> senna',
#  ' <pair> mucositis <sep> oral wound care products',
#  ' <pair> pneumonia <sep> antibiotics',
#  ' <pair> retaining fluid <sep> water pill',
#  ' <pair> blood counts <sep> filgrastim',
#  ' <pair> prevention of infection <sep> fluconazole',
#  ' <pair> prevention of infection <sep> acyclovir',
#  ' <pair> stomach <sep> ranitidine',
#  ' <pair> pain <sep> oxycontin',
#  ' <pair> prevent constipation <sep> colace',
#  ' <pair> prevent constipation <sep> senna',
#  ' <pair> fluid in your legs <sep> lasix',
#  ' <pair> mucositis pain <sep> gelclair',
#  ' <pair> shingles <sep> lyrica',
#  ' <pair> chest pain <sep> asa',
#  ' <pair> stroke <sep> asa',
#  ' <pair> hypernatremia <sep> d5w',
#  ' <pair> stroke <sep> keppra',
#  ' <pair> glaucoma <sep> levobunolol',
#  ' <pair> glaucoma <sep> xalatan',
#  ' <pair> glaucoma <sep> travatan',
#  ' <pair> hypernatremia <sep> fluids',
#  ' <pair> acute drop in your blood count <sep> blood',
#  ' <pair> cataracts <sep> levobunolol',
#  ' <pair> hypoglycemia <sep> insulin',
#  ' <pair> hypoglycemia <sep> insulin',
#  ' <pair> hypoglycemia <sep> insulin',
#  ' <pair> chronic diastolic heart failure <sep> cardiac medications',
#  ' <pair> cad <sep> asa',
#  ' <pair> cad <sep> plavix',
#  ' <pair> cad <sep> statin',
#  ' <pair> cad <sep> bb',
#  ' <pair> atrial fibrillation <sep> coumadin',
#  ' <pair> atrial fibrillation <sep> metoprolol',
#  ' <pair> afib <sep> coumadin',
#  ' <pair> constipation <sep> laxatives',
#  ' <pair> hyponatremia to 120 <sep> ns',
#  ' <pair> concern for sepsis <sep> ceftriaxone',
#  ' <pair> adrenal insufficiency <sep> decadron',
#  ' <pair> diabetes mellitus, type 2 <sep> insulin',
#  ' <pair> cad <sep> asa',
#  ' <pair> cad <sep> plavix',
#  ' <pair> cad <sep> statin',
#  ' <pair> hypertension <sep> bb',
#  ' <pair> atrial fibrillation <sep> coumadin',
#  ' <pair> atrial fibrillation <sep> lovenox',
#  ' <pair> atrial fibrillation <sep> lovenox',
#  ' <pair> atrial fibrillation <sep> coumadin',
#  ' <pair> atrial fibrillation <sep> coumadin',
#  ' <pair> anticoagulation <sep> coumadin',
#  ' <pair> fsg 30 <sep> d50',
#  ' <pair> type ii diabetes <sep> insulin',
#  ' <pair> esophageal varaces <sep> nadolol',
#  ' <pair> diuresis <sep> torsemide',
#  ' <pair> rul hap <sep> cefepime',
#  ' <pair> rul hap <sep> vancomycin',
#  ' <pair> hcap <sep> vanc',
#  ' <pair> c.diff <sep> vanc',
#  ' <pair> c.diff <sep> flagyl',
#  ' <pair> c.diff <sep> flagyl',
#  ' <pair> c.diff <sep> vanco',
#  ' <pair> inr of 10 <sep> vit k',
#  ' <pair> mechanical mitral valve <sep> heparin',
#  ' <pair> esophageal varices <sep> nadolol',
#  ' <pair> hypertension <sep> amlodipine',
#  ' <pair> hypertension <sep> spironolactone',
#  ' <pair> health care associated pneumonia <sep> meropenem',
#  ' <pair> c. difficile infection <sep> flagyl',
#  ' <pair> c. difficile infection <sep> vanc',
#  ' <pair> congestive heart failure <sep> bumex',
#  ' <pair> mitral valve replacement <sep> hep',
#  ' <pair> mitral valve replacement <sep> coumadin',
#  ' <pair> arrythmia <sep> dofetilide',
#  ' <pair> dyspnea <sep> albuterol sulfate',
#  ' <pair> dyspnea <sep> morphine',
#  ' <pair> line flush <sep> sodium chloride',
#  ' <pair> goal inr 2.5 - 3.5 <sep> warfarin',
#  ' <pair> shortness of breath <sep> albuterol sulfate',
#  ' <pair> wheezing <sep> albuterol sulfate',
#  ' <pair> pain <sep> morphine',
#  ' <pair> shortness of breath <sep> morphine',
#  ' <pair> wheezing <sep> morphine',
#  ' <pair> gi bleed <sep> rbcs',
#  ' <pair> chronic obstructive pulmonary disease <sep> o2',
#  ' <pair> infection in your gi tract <sep> antiobiotics',
#  ' <pair> idiopathic pulmonary fibrosis <sep> prednisone',
#  ' <pair> goal inr 2.5 to 3.5 <sep> coumadin',
#  ' <pair> ipf <sep> prednisone',
#  ' <pair> copd <sep> prednisone',
#  ' <pair> her heart valve <sep> heparin',
#  ' <pair> gastric varices <sep> nadolol',
#  ' <pair> incisional pain <sep> ultram',
#  ' <pair> perioperative <sep> cefazolin',
#  ' <pair> perioperative <sep> antibiotics',
#  ' <pair> nausea <sep> antiemtics',
#  ' <pair> pain management <sep> ultram',
#  ' <pair> blood glucose management <sep> lantus',
#  ' <pair> diuresiss <sep> lasix',
#  ' <pair> lower extremity edema <sep> lasix',
#  ' <pair> decreased hematocrit <sep> iron',
#  ' <pair> decreased hematocrit <sep> transfusions',
#  ' <pair> anxiety <sep> lorazepam',
#  ' <pair> chest pain <sep> nitrostat',
#  ' <pair> pain <sep> ultram',
#  ' <pair> wheezing <sep> albuterol sulfate',
#  ' <pair> non-small cell lung cancer <sep> taxol',
#  ' <pair> non-small cell lung cancer <sep> carboplatin',
#  ' <pair> non-small cell lung cancer <sep> avastin',
#  ' <pair> pulmonary emboli <sep> lovenox',
#  ' <pair> hypertension <sep> atenolol',
#  ' <pair> hypertension <sep> chlorthalidone',
#  ' <pair> hypotensive <sep> fluid',
#  ' <pair> nsclca <sep> carboplatin',
#  ' <pair> nsclca <sep> avastin',
#  ' <pair> nsclca <sep> taxol',
#  ' <pair> intermittent atrial tachycardia <sep> atenolol',
#  ' <pair> pain <sep> acetaminophen',
#  ' <pair> constipation <sep> docusate sodium',
#  ' <pair> itching <sep> fexofenadine',
#  ' <pair> oral sores <sep> lidocaine hcl',
#  ' <pair> shortness of breath <sep> formoterol fumarate',
#  ' <pair> wheezing <sep> formoterol fumarate',
#  ' <pair> pes <sep> heparin',
#  ' <pair> pes <sep> lovenox',
#  ' <pair> prevent clot formation <sep> lovenox',
#  ' <pair> nsclca <sep> chemo',
#  ' <pair> biliary sepsis <sep> zosyn',
#  ' <pair> biliary sepsis <sep> levo',
#  ' <pair> biliary sepsis <sep> flagyl',
#  ' <pair> hypotensive <sep> ivf',
#  ' <pair> hypotensive <sep> pressors',
#  ' <pair> hemodynamic support <sep> levo',
#  ' <pair> hemodynamic support <sep> dopamine',
#  ' <pair> hemodynamic support <sep> vasopressin',
#  ' <pair> hemodynamic support <sep> pressor',
#  ' <pair> low random cortisol <sep> steroid',
#  ' <pair> low random cortisol <sep> dexamethasone',
#  ' <pair> low random cortisol <sep> hydrocortisone',
#  ' <pair> low random cortisol <sep> fludrocortisone',
#  ' <pair> urosepsis <sep> cipro',
#  ' <pair> rapid afib with decompensation <sep> levophed',
#  ' <pair> rapid afib with decompensation <sep> vasopressin',
#  ' <pair> rapid afib with decompensation <sep> dopa',
#  ' <pair> rapid afib with decompensation <sep> pressors',
#  ' <pair> rapid afib with decompensation <sep> amio',
#  ' <pair> afib <sep> amiodarone',
#  ' <pair> afib <sep> amiodarone',
#  ' <pair> afib <sep> dopamine',
#  ' <pair> hypotension <sep> pressors',
#  ' <pair> anticoagulation <sep> fondaparinux',
#  ' <pair> anticoagulation <sep> coumadin',
#  ' <pair> diuresed <sep> lasix',
#  ' <pair> sepsis <sep> steroids',
#  ' <pair> sepsis <sep> flagyl',
#  ' <pair> sepsis <sep> pressors',
#  ' <pair> sepsis <sep> vanco',
#  ' <pair> sepsis <sep> zosyn',
#  ' <pair> sepsis <sep> lev',
#  ' <pair> diuresis <sep> bumex',
#  ' <pair> bladder spasms <sep> oxybutynin',
#  ' <pair> anticoagulation <sep> fondaparinux',
#  ' <pair> anticoagulation <sep> coumadin',
#  ' <pair> atrial fibrillation <sep> fondaparinux',
#  ' <pair> atrial fibrillation <sep> coumadin',
#  ' <pair> low ejection fraction <sep> fondaparinux',
#  ' <pair> low ejection fraction <sep> coumadin',
#  ' <pair> rheumatoid arthritis <sep> mtx',
#  ' <pair> rheumatoid arthritis <sep> remicaide',
#  ' <pair> e. coli <sep> cipro',
#  ' <pair> ra <sep> mtx',
#  ' <pair> ra <sep> remicaide',
#  ' <pair> febrile <sep> ivf',
#  ' <pair> febrile <sep> ceftaz',
#  ' <pair> febrile <sep> clinda',
#  ' <pair> febrile <sep> antibiotics',
#  ' <pair> glucose intolerance <sep> ssi',
#  ' <pair> pain <sep> acetaminophen',
#  ' <pair> fever <sep> acetaminophen',
#  ' <pair> incisional pain <sep> analgesia',
#  ' <pair> av paced <sep> phenylephrine',
#  ' <pair> dm <sep> insulin',
#  ' <pair> coronary artery disease <sep> beta-blockers',
#  ' <pair> coronary artery disease <sep> statin',
#  ' <pair> coronary artery disease <sep> aspirin',
#  ' <pair> coronary artery disease <sep> diuretics',
#  ' <pair> seizure <sep> dilantin',
#  ' <pair> cardiogenic shock <sep> pressors',
#  ' <pair> cardiogenic shock <sep> pressors',
#  ' <pair> inotropic effect <sep> dobutamine',
#  ' <pair> low co <sep> dobutamine',
#  ' <pair> encephalopathy <sep> lactulose',
#  ' <pair> dm <sep> insulin',
#  ' <pair> diabetes mellitus <sep> insulin',
#  ' <pair> seizure <sep> dilantin',
#  ' <pair> temp 102.5 <sep> tylenol',
#  ' <pair> temp 102.5 <sep> antibiotics',
#  ' <pair> temp 102.5 <sep> kefzol',
#  ' <pair> temp 102.5 <sep> vanco',
#  ' <pair> temp 102.5 <sep> cipro',
#  ' <pair> temp 102.5 <sep> flagyl',
#  ' <pair> constipated <sep> metamucil',
#  ' <pair> constipated <sep> milk of magnesia',
#  ' <pair> afib <sep> coumadin',
#  ' <pair> af <sep> warfarin',
#  ' <pair> hypotension <sep> pressor',
#  ' <pair> pain <sep> dilaudid',
#  ' <pair> afib <sep> fundaperinox',
#  ' <pair> afib <sep> coumadin',
#  ' <pair> pain control <sep> sedative medications',
#  ' <pair> pain control <sep> sedative medications (dilaudid)',
#  ' <pair> constipation <sep> magnesium hydroxide',
#  ' <pair> constipation <sep> bisacodyl',
#  ' <pair> itching <sep> diphenhydramine hcl',
#  ' <pair> agitation <sep> haldol',
#  ' <pair> anxiety <sep> klonipin',
#  ' <pair> copd <sep> albuterol',
#  ' <pair> anxiety <sep> klonipin',
#  ' <pair> rate control <sep> diltiazem',
#  ' <pair> rate control <sep> diltiazem',
#  ' <pair> better rate control <sep> dilt',
#  " <pair> crohn's disease <sep> mesalamine dr",
#  ' <pair> proph <sep> ppi',
#  ' <pair> proph <sep> heparin',
#  ' <pair> wheezing <sep> albuterol sulfate',
#  ' <pair> cough <sep> dextromethorphan- guaifenesin',
#  ' <pair> air hunger <sep> morphine sulfate',
#  ' <pair> aggitation <sep> clonazepa m',
#  ' <pair> tachtpneic <sep> nebs',
#  ' <pair> respiratory status <sep> nebs',
#  ' <pair> left sided cp <sep> ntg',
#  ' <pair> ateral st depressions <sep> heparin',
#  ' <pair> elevated blood glucose levels <sep> insulin',
#  ' <pair> copd <sep> atrovent',
#  ' <pair> copd <sep> montelukast',
#  ' <pair> copd <sep> azithromycin',
#  ' <pair> copd <sep> steroid',
#  ' <pair> copd <sep> azithromycin',
#  ' <pair> diabetes mellitus <sep> nph',
#  ' <pair> hemorrhage <sep> erythromycin',
#  ' <pair> pain <sep> morphine sulfate',
#  ' <pair> anxiety <sep> clonazepa m',
#  ' <pair> blood pressure <sep> metoprolol',
#  ' <pair> blood pressure <sep> labetalol',
#  ' <pair> bilateral subdural hematomas <sep> antiepileptics',
#  ' <pair> positive blood cultures <sep> vancomycin',
#  ' <pair> positive blood cultures <sep> meropenem',
#  ' <pair> positive blood cultures <sep> vancomycin',
#  ' <pair> positive blood cultures <sep> cefepime',
#  ' <pair> better coverage of gut pathogens <sep> vancomycin',
#  ' <pair> better coverage of gut pathogens <sep> zosyn',
#  ' <pair> fungal pathogens <sep> micafungin',
#  ' <pair> gpcs in chains <sep> vancomycin',
#  ' <pair> vre coverage <sep> daptomycin',
#  ' <pair> type ii dm <sep> metformin',
#  ' <pair> apml <sep> atra',
#  ' <pair> toxic metabolic encephalopathy <sep> haldol',
#  ' <pair> tls <sep> allopurinol',
#  ' <pair> tls <sep> rasburicase',
#  ' <pair> infected cyst <sep> abx',
#  ' <pair> diurese <sep> metolazone',
#  ' <pair> diurese <sep> lasix',
#  ' <pair> elevated glucose <sep> insulin',
#  ' <pair> mrsa bacteremia <sep> vancomycin',
#  ' <pair> high grade s aureus bacteremia <sep> vancomycin',
#  ' <pair> to prevent encephalopathy <sep> lactulose',
#  ' <pair> to prevent encephalopathy <sep> rifaximin',
#  ' <pair> generalized edema <sep> lasix',
#  ' <pair> abdominal pain <sep> dilaudid',
#  ' <pair> hypertensive <sep> lopressor',
#  ' <pair> immunosuppression <sep> steroids',
#  ' <pair> immunosuppression <sep> cellcept',
#  ' <pair> autoimmune hepatitis <sep> prednisone',
#  ' <pair> 2+ leg edema <sep> lasix',
#  ' <pair> shortness of breath after eating a peanut butter <sep> benadryl',
#  ' <pair> nausea <sep> ondansetro n',
#  ' <pair> pain <sep> oxycodone',
#  ' <pair> persistent abdominal pain <sep> pain med',
#  ' <pair> gastroenteritis <sep> zofran',
#  ' <pair> gastroenteritis <sep> dilaudid',
#  ' <pair> occult anemia <sep> prbc',
#  ' <pair> high ascites drain output <sep> fluid',
#  ' <pair> high ascites drain output <sep> albumin',
#  ' <pair> acinetobacter baumanii <sep> cetriaxone',
#  ' <pair> hypertensive <sep> morphine',
#  ' <pair> diffuse itching and burning of the skin <sep> benadryl',
#  ' <pair> food allergens <sep> epipen',
#  ' <pair> wound cultures <sep> antibiotics',
#  ' <pair> pain <sep> hydromorphone',
#  ' <pair> diverticulitis <sep> antibiotic',
#  ' <pair> poor po intake <sep> ivf',
#  ' <pair> prophylaxis <sep> ppi',
#  ' <pair> dvt prophylaxis <sep> heparin',
#  ' <pair> gi prophylaxis <sep> ppi',
#  ' <pair> pain <sep> acetaminophen',
#  ' <pair> heart burn <sep> calcium carbonate',
#  ' <pair> pain <sep> oxycodone',
#  ' <pair> nausea <sep> ondansetron',
#  ' <pair> carcinoma of lung <sep> cisplatin',
#  ' <pair> carcinoma of lung <sep> etoposide',
#  ' <pair> blood pressure control <sep> amlodipine',
#  ...]

# %%
vocab = build_vocab_from_iterator(all_reason_drug_pairs,
                                 specials=['<unk>', '<reas>', '<drug>',
                                           '<pair>', '<sep>'])

# %%
len(vocab)
# Out:
# 2501

# %%
import torch
from torch import nn, Tensor
import torch.nn.functional as f
from torch.nn import TransformerEncoder, TransformerEncoderLayer

# %%
from torch.utils.data import Dataset

class ReasonDrugDataset(Dataset):
    def __init__(self):

# %%
entities[entities['id'] == 'T76']
# Out:
#      id label  start   stop   value
# 68  T76  Drug  13651  13657  ultram
